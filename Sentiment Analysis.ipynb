# %%
import pandas as pd
import openpyxl

# %%
pew_df= pd.read_excel("C:/Users/tauny/Desktop/Schulich - School/Classes/Summer 2024 - Semester 1/AI Fundamentals/Assignments/Part 2/AI-Human-PewData.xlsx", engine= 'openpyxl')

# %%
print(pew_df.head())
print(pew_df.info())
print(pew_df.describe())
# Out:
#    Unnamed: 0    QKEY INTERVIEW_START_W99   INTERVIEW_END_W99 DEVICE_TYPE_W99  \
# 0           0  100260 2021-11-03 14:25:27 2021-11-03 14:45:34       Laptop/PC
# 1           1  100314 2021-11-04 12:35:35 2021-11-04 12:55:29      Smartphone
# 2           2  100363 2021-11-03 20:23:43 2021-11-03 20:36:24      Smartphone
# 3           3  100598 2021-11-02 13:01:05 2021-11-04 12:37:42       Laptop/PC
# 4           4  100637 2021-11-02 12:32:58 2021-11-02 12:46:23       Laptop/PC
#
#   LANG_W99 FORM_W99    XTABLET_W99        TECH1_W99  \
# 0  English   Form 2  Non-tablet HH              NaN
# 1  English   Form 1  Non-tablet HH  Mostly positive
# 2  English   Form 1  Non-tablet HH  Mostly positive
# 3  English   Form 2  Non-tablet HH              NaN
# 4  English   Form 2  Non-tablet HH              NaN
#
#                                SC1_W99  ...       F_PARTYLN_FINAL  \
# 0                      Mostly positive  ...                   NaN
# ...

# %%
# Check for missing values in each column
missing_values = pew_df.isnull().sum()

# %%
# Print columns with missing values
print(missing_values)
# Out:
# Unnamed: 0               0
# QKEY                     0
# INTERVIEW_START_W99      0
# INTERVIEW_END_W99        0
# DEVICE_TYPE_W99          0
#                       ...
# F_IDEO                   0
# F_INTFREQ              173
# F_VOLSUM                 0
# F_INC_TIER2              0
# WEIGHT_W99               0
# Length: 215, dtype: int64

# %%
# Display info about the DataFrame
pew_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10260 entries, 0 to 10259
# Columns: 215 entries, Unnamed: 0 to WEIGHT_W99
# dtypes: datetime64[ns](2), float64(1), int64(2), object(210)
# memory usage: 16.8+ MB

# %%
# Fill missing values with a specified value
pew_df_filled = pew_df.fillna('None')
print("DataFrame with missing values filled with 'None':")
print(pew_df_filled)
# Out:
# DataFrame with missing values filled with 'None':
#        Unnamed: 0          QKEY INTERVIEW_START_W99   INTERVIEW_END_W99  \
# 0               0        100260 2021-11-03 14:25:27 2021-11-03 14:45:34
# 1               1        100314 2021-11-04 12:35:35 2021-11-04 12:55:29
# 2               2        100363 2021-11-03 20:23:43 2021-11-03 20:36:24
# 3               3        100598 2021-11-02 13:01:05 2021-11-04 12:37:42
# 4               4        100637 2021-11-02 12:32:58 2021-11-02 12:46:23
# ...           ...           ...                 ...                 ...
# 10255       10255  202101013246 2021-11-02 15:06:47 2021-11-02 15:21:18
# 10256       10256  202101013292 2021-11-02 12:18:58 2021-11-02 12:32:49
# 10257       10257  202101013344 2021-11-04 16:30:29 2021-11-06 11:08:56
# 10258       10258  202101013446 2021-11-06 15:22:13 2021-11-06 16:10:36
# 10259       10259  202101013477 2021-11-02 23:46:38 2021-11-02 23:56:21
#
# ...

# %%
# Check for missing values in each column
missing_values = pew_df_filled.isna().sum()
print(missing_values)
# Out:
# Unnamed: 0             0
# QKEY                   0
# INTERVIEW_START_W99    0
# INTERVIEW_END_W99      0
# DEVICE_TYPE_W99        0
#                       ..
# F_IDEO                 0
# F_INTFREQ              0
# F_VOLSUM               0
# F_INC_TIER2            0
# WEIGHT_W99             0
# Length: 215, dtype: int64

# %%
# Display info about the DataFrame
pew_df_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10260 entries, 0 to 10259
# Columns: 215 entries, Unnamed: 0 to WEIGHT_W99
# dtypes: datetime64[ns](2), float64(1), int64(2), object(210)
# memory usage: 16.8+ MB

# %%
print(pew_df_filled)
# Out:
#        Unnamed: 0          QKEY INTERVIEW_START_W99   INTERVIEW_END_W99  \
# 0               0        100260 2021-11-03 14:25:27 2021-11-03 14:45:34
# 1               1        100314 2021-11-04 12:35:35 2021-11-04 12:55:29
# 2               2        100363 2021-11-03 20:23:43 2021-11-03 20:36:24
# 3               3        100598 2021-11-02 13:01:05 2021-11-04 12:37:42
# 4               4        100637 2021-11-02 12:32:58 2021-11-02 12:46:23
# ...           ...           ...                 ...                 ...
# 10255       10255  202101013246 2021-11-02 15:06:47 2021-11-02 15:21:18
# 10256       10256  202101013292 2021-11-02 12:18:58 2021-11-02 12:32:49
# 10257       10257  202101013344 2021-11-04 16:30:29 2021-11-06 11:08:56
# 10258       10258  202101013446 2021-11-06 15:22:13 2021-11-06 16:10:36
# 10259       10259  202101013477 2021-11-02 23:46:38 2021-11-02 23:56:21
#
#       DEVICE_TYPE_W99 LANG_W99 FORM_W99    XTABLET_W99        TECH1_W99  \
# ...

# %%
# Check for duplicates in 'QKEY' column
duplicates = pew_df_filled[pew_df_filled['QKEY'].duplicated(keep=False)]

# Display the rows with duplicate 'QKEY' values
print(duplicates)
# Out:
# Empty DataFrame
# ...

# %%
#selecting specific columns and rows
demographic_df= pew_df_filled.iloc[:, 182:215]
demographic_df.head()
# Out:
#   F_RELCOM3CAT           F_METRO  F_CREGION         F_CDIVISION F_AGECAT  \
# 0       Medium      Metropolitan       West             Pacific      65+
# 1       Medium  Non-metropolitan    Midwest  East North Central      65+
# 2       Medium      Metropolitan  Northeast     Middle Atlantic    30-49
# 3       Medium      Metropolitan       West             Pacific    50-64
# 4       Medium      Metropolitan      South      South Atlantic      65+
#
#   F_GENDER          F_EDUCCAT                       F_EDUCCAT2 F_HISP  \
# 0    A man  College graduate+  College graduate/some post grad     No
# 1    A man       Some College          Some college, no degree     No
# 2  A woman  College graduate+                     Postgraduate     No
# 3  A woman  College graduate+                     Postgraduate     No
# 4  A woman       Some College               Associate's degree     No
#
#   F_HISP_ORIGIN  ...       F_PARTYLN_FINAL F_PARTYSUM_FINAL  \
# ...

# %%
# Get the total number of columns in your demographic df
total_sample = len(demographic_df)
print(total_sample)
# Out:
# 10260

# %%
# Iterate over each column index
for column_index in demographic_df:
    # Group by the current column
    #count = demographic_df.groupby(demographic_df.columns[column_index]).size()
    count = demographic_df.groupby(column_index).size()
    # Calculate percentage for each group
    percentage_count = (count / total_sample)*100

    # Print the result
    print(percentage_count)

    # Print an empty line
    print()
# Out:
# F_RELCOM3CAT
# DK/Ref     0.740741
# High      21.033138
# Low       24.093567
# Medium    54.132554
# dtype: float64
#
# F_METRO
# Metropolitan        87.91423
# Non-metropolitan    12.08577
# dtype: float64
#
# F_CREGION
# Midwest      21.900585
# Northeast    16.052632
# South        39.298246
# West         22.748538
# dtype: float64
#
# F_CDIVISION
# East North Central    14.571150
# East South Central     5.243665
# Middle Atlantic       11.423002
# Mountain               8.352827
# New England            4.629630
# Pacific               14.395712
# South Atlantic        23.138402
# West North Central     7.329435
# West South Central    10.916179
# dtype: float64
#
# F_AGECAT
# 18-29       8.723197
# 30-49      32.436647
# 50-64      28.781676
# 65+        29.707602
# Refused     0.350877
# dtype: float64
#
# F_GENDER
# A man                44.337232
# A woman              54.853801
# In some other way     0.584795
# Refused               0.224172
# dtype: float64
#
# ...

# %%
#selecting specific columns and rows
general_perception_df= pew_df_filled.iloc[:, 8:36]
general_perception_df.head()
# Out:
#          TECH1_W99                              SC1_W99  \
# 0             None                      Mostly positive
# 1  Mostly positive                                 None
# 2  Mostly positive                                 None
# 3             None                      Mostly positive
# 4             None  Equal positive and negative effects
#
#                       CNCEXC_W99      EXCITEOE_W99_OE1 EXCITEOE_W99_OE2  \
# 0  Equally concerned and excited                  None             None
# 1    More excited than concerned  Don't know/No answer             None
# 2  Equally concerned and excited                  None             None
# 3  Equally concerned and excited                  None             None
# 4  Equally concerned and excited                  None             None
#
#   EXCITEOE_W99_OE3 EXCITEOE_REFUSED_W99 CONCERNOE_W99_OE1 CONCERNOE_W99_OE2  \
# 0             None            Not asked              None              None
# ...

# %%
# Iterate over each column
for column_name in general_perception_df.columns:
    # Group by the current column
    count = general_perception_df.groupby(column_name).size()
    
    # Calculate percentage for each group
    percentage_count = (count / total_sample) * 100

    # Print the result
    print(percentage_count)

    # Print an empty line
    print()
# Out:
# TECH1_W99
# Equal positive and negative effects    19.844055
# Mostly negative                         4.697856
# Mostly positive                        25.604288
# None                                   49.775828
# Refused                                 0.077973
# dtype: float64
#
# SC1_W99
# Equal positive and negative effects    11.452242
# Mostly negative                         2.553606
# Mostly positive                        35.584795
# None                                   50.224172
# Refused                                 0.185185
# dtype: float64
#
# CNCEXC_W99
# Equally concerned and excited    44.805068
# More concerned than excited      36.773879
# More excited than concerned      18.060429
# Refused                           0.360624
# dtype: float64
#
# EXCITEOE_W99_OE1
# AI is interesting, exciting                               0.799220
# Don't know/No answer                                      2.797271
# ...

# %%
#selecting specific columns and rows
gene_editor_df= pew_df_filled.iloc[:, 139:161]
gene_editor_df.head()
# Out:
#        GENEV1_W99 GENEV2_W99                                   GENEV3_W99  \
# 0  Nothing at all   Not sure  Yes, I would probably want this for my baby
# 1            None       None                                         None
# 2            None       None                                         None
# 3  Nothing at all   Not sure  Yes, I would probably want this for my baby
# 4        A little   Not sure  Yes, I would probably want this for my baby
#
#               GENEV4_a_W99               GENEV4_b_W99           GENEV4_c_W99  \
# 0    Probably would happen  Probably would NOT happen  Probably would happen
# 1                     None                       None                   None
# 2                     None                       None                   None
# 3  Definitely would happen      Probably would happen  Probably would happen
# 4  Definitely would happen      Probably would happen  Probably would happen
#
# ...

# %%
# Iterate over each column
for column_name in gene_editor_df.columns:
    # Group by the current column
    count = gene_editor_df.groupby(column_name).size()
    
    # Calculate percentage for each group
    percentage_count = (count / total_sample) * 100

    # Print the result
    print(percentage_count)

    # Print an empty line
    print()
# Out:
# GENEV1_W99
# A little          25.536062
# A lot              4.307992
# None              50.224172
# Nothing at all    19.775828
# Refused            0.155945
# dtype: float64
#
# GENEV2_W99
# Bad idea for society     14.766082
# Good idea for society    16.539961
# None                     50.224172
# Not sure                 18.206628
# Refused                   0.263158
# dtype: float64
#
# GENEV3_W99
# No, I would definitely NOT want this for my baby    10.438596
# No, I would probably NOT want this for my baby      11.968811
# None                                                50.224172
# Refused                                              1.237817
# Yes, I would definitely want this for my baby        7.943470
# Yes, I would probably want this for my baby         18.187135
# dtype: float64
#
# GENEV4_a_W99
# Definitely would NOT happen     1.588694
# Definitely would happen        23.957115
# None                           50.224172
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bar Chart
sns.countplot(x='GENEV3_W99', data=gene_editor_df)
plt.title('Public Perception of Gene Editing')
plt.xlabel('Perception')
plt.ylabel('Count')
plt.show()

# %%
# Pie Chart
age_groups = demographic_df['F_AGECAT'].value_counts()
plt.pie(age_groups, labels=age_groups.index, autopct='%1.1f%%', startangle=140)
plt.title('Age Group Distribution')
plt.show()

# %%
pew_df_filled= pew_df_filled[pew_df_filled.F_AGECAT!= 'Refused']

# %%
pew_df_filled= pew_df_filled[pew_df_filled.F_EDUCCAT2!= 'Refused']

# %%
pew_df_filled= pew_df_filled[pew_df_filled['FORM_W99']=='Form 2']

# %%
pew_df_filled.groupby(['F_AGECAT', 'GENEV3_W99']).size()
# Out:
# F_AGECAT  GENEV3_W99
# 18-29     No, I would definitely NOT want this for my baby     66
#           No, I would probably NOT want this for my baby      104
#           Refused                                               9
#           Yes, I would definitely want this for my baby        62
#           Yes, I would probably want this for my baby         196
# 30-49     No, I would definitely NOT want this for my baby    403
#           No, I would probably NOT want this for my baby      427
#           Refused                                              22
#           Yes, I would definitely want this for my baby       288
#           Yes, I would probably want this for my baby         540
# 50-64     No, I would definitely NOT want this for my baby    339
#           No, I would probably NOT want this for my baby      352
#           Refused                                              37
#           Yes, I would definitely want this for my baby       205
# ...

# %%
frequency_table= pew_df_filled.groupby(['F_AGECAT', 'F_EDUCCAT2','GENEV3_W99']).size().unstack()

# %%
# Calculate the total count for each group
total_counts = frequency_table.sum(axis=1)  # Sum along columns to get totals for each row

# Divide each cell by its respective total count and multiply by 100 to get percentages
percentage_table = (frequency_table.div(total_counts, axis=0) * 100).round(2)  # round to 2 decimal places

# Print or use percentage_table as needed
print(percentage_table)
# Out:
# GENEV3_W99                                No, I would definitely NOT want this for my baby  \
# F_AGECAT F_EDUCCAT2
# 18-29    Associate's degree                                                          12.77
#          College graduate/some post grad                                              8.33
#          High school graduate                                                        27.45
#          Less than high school                                                       26.09
#          Postgraduate                                                                14.29
#          Some college, no degree                                                     18.56
# 30-49    Associate's degree                                                          25.00
#          College graduate/some post grad                                             21.80
#          High school graduate                                                        31.34
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you already have 'percentage_table' as described earlier

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(percentage_table, annot=True, fmt=".2f", cmap="YlGnBu", cbar=True)
plt.title('Percentage Distribution of Responses')
plt.xlabel('Response to "GENEV3_W99"')
plt.ylabel('Age Group and Education Level')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Reshape the percentage_table for easier plotting
percentage_table = percentage_table.stack().reset_index()
percentage_table.columns = ['F_AGECAT', 'F_EDUCCAT2', 'GENEV3_W99', 'Percentage']

# Plot grouped bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x='F_AGECAT', y='Percentage', hue='GENEV3_W99', data=percentage_table, palette='Set2')
plt.title('Percentage Distribution of Responses by Age Group')
plt.xlabel('Age Group and Education Level')
plt.ylabel('Percentage')
plt.xticks(rotation=45)
plt.legend(title='Response to "GENEV3_W99"')
plt.tight_layout()
plt.show()

# %%
pip install pandas numpy nltk scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import nltk
from nltk.corpus import stopwords
import re

# %%
# Define the columns to be considered for NLP (based on identified questions)
nlp_columns = [
    'GENEV5_W99', 'GENEV7_W99', 'GENEV8_W99', 'GENEV10_W99', 'GENEV11_W99', 'GENEV12_a_W99', 'GENEV12_b_W99', 'GENEV12_c_W99', 'GENEV13_a_W99', 'GENEV13_b_W99'
]

# Combine the text columns into a single column for NLP processing
pew_df_filled['combined_text'] = pew_df_filled[nlp_columns].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)

# %%
# Preprocess the text data
def preprocess_text(text):
    text = re.sub(r'\d+', '', text)  # Remove digits
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = text.lower()  # Convert to lowercase
    return text

text_data= pew_df_filled['processed_text'] = pew_df_filled['combined_text'].apply(preprocess_text)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tauny\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Initialize TF-IDF Vectorizer
stop_words = list(stopwords.words('english'))  # Convert set to list
vectorizer = TfidfVectorizer(stop_words=stop_words, max_features=1000)
tfidf_matrix = vectorizer.fit_transform(pew_df_filled['processed_text'])

# %%
# Initialize LDA for topic modeling
n_topics = 5
lda = LatentDirichletAllocation(n_components=n_topics, random_state=42)
lda.fit(tfidf_matrix)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
# Display the top words for each topic
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

tf_feature_names = vectorizer.get_feature_names_out()
display_topics(lda, tf_feature_names, 10)
# Out:
# Topic 0:
# difference much make acceptable cross crosses nature line meddling oppose
# Topic 1:
# acceptable better higher always trying different humans gap americans lowerincome
# Topic 2:
# higher acceptable difference crosses cross meddling nature line increase americans
# Topic 3:
# difference better acceptable make much always humans different trying favor
# Topic 4:
# less acceptable higher cross line meddling nature crosses gap lowerincome

# %%
x = ['A', 'B', 'C', 'D', 'E']
y1 = np.array(['difference', 'much', 'make', 'acceptable', 'cross', 'crosses', 'nature', 'line', 'meddling', 'oppose'])
y2 = np.array(['acceptable', 'better', 'higher', 'always', 'trying', 'different', 'humans', 'gap', 'americans', 'lowerincome'])
y3 = np.array(['higher', 'acceptable', 'difference', 'crosses', 'cross', 'meddling', 'nature', 'line', 'increase', 'americans'])
y4 = np.array(['difference', 'better', 'acceptable', 'make', 'much', 'always', 'humans', 'different', 'trying', 'favor'])
y5 = np.array(['less', 'acceptable', 'higher', 'cross', 'line', 'meddling', 'nature', 'crosses', 'gap', 'lowerincome'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 2
#       1 x = ['A', 'B', 'C', 'D', 'E']
# ----> 2 y1 = np.array(['difference', 'much', 'make', 'acceptable', 'cross', 'crosses', 'nature', 'line', 'meddling', 'oppose'])
#       3 y2 = np.array(['acceptable', 'better', 'higher', 'always', 'trying', 'different', 'humans', 'gap', 'americans', 'lowerincome'])
#       4 y3 = np.array(['higher', 'acceptable', 'difference', 'crosses', 'cross', 'meddling', 'nature', 'line', 'increase', 'americans'])
#
# NameError: name 'np' is not defined

# %%
plt.bar(x, y1, color='r')
plt.bar(x, y2, bottom=y1, color='b')
plt.bar(x, y3, bottom=y1 + y2, color='y')
plt.bar(x, y4, bottom=y1 + y2 + y3, color='g')
plt.bar(x, y5, bottom= y1 + y2 + y3 +y4, color='o')
plt.xlabel("Teams")
plt.ylabel("Score")
plt.legend(["Round 1", "Round 2", "Round 3", "Round 4", "Round 5"])
plt.title("Scores by Teams in 5 Rounds")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 plt.bar(x, y1, color='r')
#       2 plt.bar(x, y2, bottom=y1, color='b')
#       3 plt.bar(x, y3, bottom=y1 + y2, color='y')
#
# NameError: name 'y1' is not defined

# %%
# Example topics (replace with your actual topics)
topics = {
    'Topic 0': ['difference', 'much', 'make', 'acceptable', 'cross', 'crosses', 'nature', 'line', 'meddling', 'oppose'],
    'Topic 1': ['acceptable', 'better', 'higher', 'always', 'trying', 'different', 'humans', 'gap', 'americans', 'lowerincome'],
    'Topic 2': ['higher', 'acceptable', 'difference', 'crosses', 'cross', 'meddling', 'nature', 'line', 'increase', 'americans'],
    'Topic 3': ['difference', 'better', 'acceptable', 'make', 'much', 'always', 'humans', 'different', 'trying', 'favor'],
    'Topic 4': ['less', 'acceptable', 'higher', 'cross', 'line', 'meddling', 'nature', 'crosses', 'gap', 'lowerincome']
}

# Plotting the topics
plt.figure(figsize=(10, 6))
for topic, keywords in topics.items():
    plt.barh(topic, len(keywords), color='skyblue')
    plt.yticks(fontsize=12)
    plt.title('Top Keywords in Each Topic', fontsize=14)
    plt.xlabel('Keyword Count', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# !pip install vaderSentiment
# !pip install wordcloud
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# {'Positive': 0.0, 'Neutral': 100.0, 'Negative': 0.0}
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Analyze sentiment for each response
def get_sentiment(text):
    sentiment = analyzer.polarity_scores(text)
    return sentiment

sentiment_scores = [get_sentiment(text) for text in text_data]

# Aggregate sentiment scores
positive = sum(1 for score in sentiment_scores if score['compound'] > 0.78)
neutral = sum(1 for score in sentiment_scores if 0.41 <= score['compound'] <= 0.77)
negative = sum(1 for score in sentiment_scores if score['compound'] < 0.4)

total = positive + neutral + negative

sentiment_distribution = {
    'Positive': (positive / total) * 100,
    'Neutral': (neutral / total) * 100,
    'Negative': (negative / total) * 100
}

# Display sentiment distribution
print(sentiment_distribution)

# Plot sentiment distribution
plt.figure(figsize=(10, 6))
plt.bar(sentiment_distribution.keys(), sentiment_distribution.values(), color=['green', 'orange', 'red'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Percentage')
plt.show()

# Generate and display word cloud
text = ' '.join(text_data)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# {'Positive': 41.644776722570214, 'Neutral': 36.53263285512225, 'Negative': 21.822590422307535}

# %%
for text, score in zip(text_data[:10], sentiment_scores[:10]):
    print(f"Text: {text}\nSentiment: {score}\n")
# Out:
# Text: this idea is meddling with nature and crosses a line we should not cross about the same as now not make much difference government will go too far regulating their use a higher standard than used for medical treatments more acceptable no difference no difference oppose not sure
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Text: as humans we are always trying to better ourselves and this idea is no different better than now increase the gap between higher and lowerincome americans government will go too far regulating their use a higher standard than used for medical treatments more acceptable more acceptable no difference favor favor
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# ...

# %%
print(sentiment_scores)

# Convert setiment scores to a dataframe to display descriptive statistics
sentiment_df= pd.DataFrame(sentiment_scores)

print(sentiment_df.describe())
# Out:
# [{'neg': 0.084, 'neu': 0.831, 'pos': 0.085, 'compound': 0.0105}, {'neg': 0.147, 'neu': 0.644, 'pos': 0.21, 'compound': 0.6133}, {'neg': 0.045, 'neu': 0.765, 'pos': 0.19, 'compound': 0.7751}, {'neg': 0.073, 'neu': 0.775, 'pos': 0.152, 'compound': 0.5374}, {'neg': 0.0, 'neu': 0.727, 'pos': 0.273, 'compound': 0.934}, {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.9187}, {'neg': 0.114, 'neu': 0.69, 'pos': 0.196, 'compound': 0.6312}, {'neg': 0.136, 'neu': 0.702, 'pos': 0.163, 'compound': 0.4149}, {'neg': 0.045, 'neu': 0.765, 'pos': 0.19, 'compound': 0.7751}, {'neg': 0.085, 'neu': 0.773, 'pos': 0.143, 'compound': 0.4843}, {'neg': 0.038, 'neu': 0.72, 'pos': 0.243, 'compound': 0.8994}, {'neg': 0.111, 'neu': 0.701, 'pos': 0.188, 'compound': 0.5755}, {'neg': 0.076, 'neu': 0.767, 'pos': 0.158, 'compound': 0.5374}, {'neg': 0.076, 'neu': 0.673, 'pos': 0.252, 'compound': 0.8674}, {'neg': 0.084, 'neu': 0.737, 'pos': 0.179, 'compound': 0.6773}, {'neg': 0.039, 'neu': 0.761, 'pos': 0.2, 'compo
# ...
