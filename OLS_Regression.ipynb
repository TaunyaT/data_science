# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import statsmodels.api as sm

# %%
from statsmodels.sandbox.regression.gmm import GMM

# %%
# Load dataset
data = pd.read_csv('C:/Users/tauny/Desktop/Schulich - School/Classes/Fall 2024 - Semester 2/Predictive Modelling/Assignments/Assignment Project/dataset_LM.csv')

# %%
data.head()
# Out:
#    Dependent Var  Explanatory Var #1  Explanatory Var #2  Explanatory Var #3  \
# 0      56.293458           13.698667           50.639873                   0
# 1      58.473431            2.714725           65.845845                   1
# 2      94.195330           11.618072           65.072497                   0
# 3      29.074583            0.818623           45.408996                   1
# 4      86.035569            9.077544           73.548021                   0
#
#    Explanatory Var #4  Explanatory Var #5  Explanatory Var #6  \
# 0          -18.568035           45.121911           11.412501
# 1          -25.105932           47.190213           10.080280
# 2           -7.897464           52.163036           11.057301
# 3          -18.316132           54.356714            5.029029
# 4          -19.204165           47.186807           12.128134
#
#    Explanatory Var #7  Explanatory Var #8  Explanatory Var #9  \
# 0           56.410757                   2          -12.281132
# ...

# %%
data
# Out:
#      Dependent Var  Explanatory Var #1  Explanatory Var #2  \
# 0        56.293458           13.698667           50.639873
# 1        58.473431            2.714725           65.845845
# 2        94.195330           11.618072           65.072497
# 3        29.074583            0.818623           45.408996
# 4        86.035569            9.077544           73.548021
# ..             ...                 ...                 ...
# 417      61.300432            0.338441           70.430598
# 418      26.309237           -1.729712           47.087996
# 419      58.350627           18.322301           53.267835
# 420      31.954003            0.436357           61.844132
# 421      50.590958           -3.107425           64.590632
#
#      Explanatory Var #3  Explanatory Var #4  Explanatory Var #5  \
# 0                     0          -18.568035           45.121911
# 1                     1          -25.105932           47.190213
# ...

# %%
data.describe()
# Out:
#        Dependent Var  Explanatory Var #1  Explanatory Var #2  \
# count     422.000000          422.000000          422.000000
# mean       67.838396            7.762058           59.725134
# std        25.676960            7.013243            9.579112
# min        -2.997183           -4.832834           44.124858
# 25%        49.482037            1.720182           51.617692
# 50%        66.780110            7.905455           59.735139
# 75%        86.801496           13.684104           67.870073
# max       133.384795           19.973331           76.973576
#
#        Explanatory Var #3  Explanatory Var #4  Explanatory Var #5  \
# count          422.000000          422.000000          422.000000
# mean             0.500000          -16.078411           50.133715
# std              0.500593            8.111197            6.975674
# min              0.000000          -29.774797           30.009511
# 25%              0.000000          -23.792637           45.423422
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Dependent Var        422 non-null    float64
#  1   Explanatory Var #1   422 non-null    float64
#  2   Explanatory Var #2   422 non-null    float64
#  3   Explanatory Var #3   422 non-null    int64
#  4   Explanatory Var #4   422 non-null    float64
#  5   Explanatory Var #5   422 non-null    float64
#  6   Explanatory Var #6   422 non-null    float64
#  7   Explanatory Var #7   422 non-null    float64
#  8   Explanatory Var #8   422 non-null    int64
#  9   Explanatory Var #9   422 non-null    float64
#  10  Explanatory Var #10  422 non-null    float64
#  11  Explanatory Var #11  422 non-null    float64
#  12  Explanatory Var #12  422 non-null    float64
#  13  Explanatory Var #13  422 non-null    int64
#  14  Explanatory Var #14  422 non-null    float64
# ...

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Scale data
scaler = MinMaxScaler(feature_range= (-1, 1))

#Fit and transform data
scaled_data = scaler.fit_transform(data)

# %%
X = data.drop('Dependent Var', axis = 1)
y = data['Dependent Var']

# %%
OLS_model = sm.OLS(y,X).fit()
OLS_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Dependent Var   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                          4.509e+04
# Date:                Fri, 18 Oct 2024   Prob (F-statistic):                        0.00
# Time:                        14:32:17   Log-Likelihood:                         -841.76
# No. Observations:                 422   AIC:                                      1714.
# Df Residuals:                     407   BIC:                                      1774.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
x_updated = sm.add_constant(X)
x_updated
# Out:
#      const  Explanatory Var #1  Explanatory Var #2  Explanatory Var #3  \
# 0      1.0           13.698667           50.639873                   0
# 1      1.0            2.714725           65.845845                   1
# 2      1.0           11.618072           65.072497                   0
# 3      1.0            0.818623           45.408996                   1
# 4      1.0            9.077544           73.548021                   0
# ..     ...                 ...                 ...                 ...
# 417    1.0            0.338441           70.430598                   0
# 418    1.0           -1.729712           47.087996                   1
# 419    1.0           18.322301           53.267835                   0
# 420    1.0            0.436357           61.844132                   0
# 421    1.0           -3.107425           64.590632                   1
#
#      Explanatory Var #4  Explanatory Var #5  Explanatory Var #6  \
# ...

# %%
OLS_model_updated = sm.OLS(y,x_updated).fit()
OLS_model_updated.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Dependent Var   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.506e+30
# Date:                Fri, 18 Oct 2024   Prob (F-statistic):               0.00
# Time:                        14:34:28   Log-Likelihood:                 12271.
# No. Observations:                 422   AIC:                        -2.451e+04
# Df Residuals:                     406   BIC:                        -2.445e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
# Generate autocorrelated terms
epsilon[0] = np.random.normal(mu,sigma,1)
for i in range (0,99):
    epsilon[i+1]=0.4*epsilon[i]+0.6*np.random.normal(mu,sigma,1)
# Out:
# C:\Users\tauny\AppData\Local\Temp\ipykernel_41180\2413408381.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   epsilon[0] = np.random.normal(mu,sigma,1)
# C:\Users\tauny\AppData\Local\Temp\ipykernel_41180\2413408381.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   epsilon[i+1]=0.4*epsilon[i]+0.6*np.random.normal(mu,sigma,1)

# %%
from scipy.linalg import toeplitz

# %%
toeplitz(np.array([1,0.5,0,0,0,0,0,0]))
# Out:
# array([[1. , 0.5, 0. , 0. , 0. , 0. , 0. , 0. ],
#        [0.5, 1. , 0.5, 0. , 0. , 0. , 0. , 0. ],
#        [0. , 0.5, 1. , 0.5, 0. , 0. , 0. , 0. ],
#        [0. , 0. , 0.5, 1. , 0.5, 0. , 0. , 0. ],
#        [0. , 0. , 0. , 0.5, 1. , 0.5, 0. , 0. ],
#        [0. , 0. , 0. , 0. , 0.5, 1. , 0.5, 0. ],
#        [0. , 0. , 0. , 0. , 0. , 0.5, 1. , 0.5],
#        [0. , 0. , 0. , 0. , 0. , 0. , 0.5, 1. ]])

# %%
# GLS Model
rho = 0.4
cov_matrix = sigma**2*toeplitz(np.append([1,rho],np.zeros(420)))
sm.GLS(y,x_updated,cov_matrix).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             GLS Regression Results
# ...
# Dep. Variable:          Dependent Var   R-squared:                       1.000
# Model:                            GLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.418e+29
# Date:                Fri, 18 Oct 2024   Prob (F-statistic):               0.00
# Time:                        14:36:41   Log-Likelihood:                 11452.
# No. Observations:                 422   AIC:                        -2.287e+04
# Df Residuals:                     406   BIC:                        -2.281e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Part C

# %%
from sklearn.model_selection import train_test_split

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.5, random_state=42)

# %%
from sklearn import linear_model as lm

# %%
lasso_model = lm.Lasso(alpha=1).fit(X_train,y_train)
lasso_model.coef_
# Out:
# array([ 1.26972628,  1.68394638,  2.02626245,  2.08756512, -0.91746375,
#        -0.        ,  0.        , -0.        ,  0.        , -0.        ,
#         0.01314162,  0.        , -0.        ,  0.        , -0.03617731])
