# %%
# load modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# setting seaborn default for plots (load seaborn's default theme & color scheme)
sns.set()

# %%
# load data set
df = pd.read_csv('https://raw.githubusercontent.com/delinai/schulich_ds1_2024/main/Datasets/Assignment1_StreamFlow_Subscription_Data.csv')

# %%
# printing the first five rows of the Streamflow dataset.
df.head()
# Out:
#    User_ID  Age  Gender Location     Subscription_Start_Date  \
# 0        1   56   Other  Central  2020-06-07 01:53:37.656934
# 1        2   69   Other     West  2024-02-21 01:53:37.656980
# 2        3   46  Female    North  2022-10-06 01:53:37.656995
# 3        4   32  Female     East  2022-01-04 01:53:37.657006
# 4        5   60  Female    North  2020-03-13 01:53:37.657017
#
#   Subscription_Type  Monthly_Payment Payment_Method  Monthly_Hours_Watched  \
# 0           Premium            19.99    Credit Card              31.513153
# 1          Standard            14.99    Credit Card               4.982277
# 2          Standard            14.99         PayPal               4.114953
# 3          Standard            14.99    Credit Card              60.244820
# 4          Standard            14.99    Credit Card               4.711855
#
#   Favorite_Genre Devices_Used  Average_Session_Length  Content_ID  \
# 0         Action           PC                1.195762        1023
# ...

# %%
# determining how many rows and columns there are
df.shape
# Out:
# (1000, 17)

# %%
# displaying different values of numeric data types
df.describe()
# Out:
#            User_ID          Age  Monthly_Payment  Monthly_Hours_Watched  \
# count  1000.000000  1000.000000      1000.000000            1000.000000
# mean    500.500000    44.385000        14.580000              19.071653
# std     288.819436    15.321669         3.404922              19.279140
# min       1.000000    18.000000         9.990000               0.041574
# 25%     250.750000    31.750000         9.990000               5.490739
# 50%     500.500000    45.000000        14.990000              13.361219
# 75%     750.250000    57.000000        14.990000              26.471636
# max    1000.000000    70.000000        19.990000             139.170408
#
#        Average_Session_Length   Content_ID  Rating_Given      Churned
# count             1000.000000  1000.000000   1000.000000  1000.000000
# mean                 1.893771  1049.201000      3.030000     0.246000
# std                  1.868852    29.268058      1.422365     0.430894
# ...

# %%
# 139.17 hours watched and 11.41 session length are outliers to review

# display more information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   User_ID                  1000 non-null   int64
#  1   Age                      1000 non-null   int64
#  2   Gender                   1000 non-null   object
#  3   Location                 1000 non-null   object
#  4   Subscription_Start_Date  1000 non-null   object
#  5   Subscription_Type        1000 non-null   object
#  6   Monthly_Payment          1000 non-null   float64
#  7   Payment_Method           1000 non-null   object
#  8   Monthly_Hours_Watched    1000 non-null   float64
#  9   Favorite_Genre           1000 non-null   object
#  10  Devices_Used             1000 non-null   object
#  11  Average_Session_Length   1000 non-null   float64
#  12  Content_ID               1000 non-null   int64
#  13  Rating_Given             1000 non-null   int64
# ...

# %%
# to understand the ouput itself (Seaborn)
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# the graph shows that age is fairly dispersed: top subscribers are 20's, 40's-50's, and 65+; lowest subsciber groups are 25-35 and 50-60.

# graphical representation for hours watched
sns.histplot(df['Monthly_Hours_Watched'])
# Out:
# <Axes: xlabel='Monthly_Hours_Watched', ylabel='Count'>

# %%
# graphical representation for devices used
sns.histplot(df['Devices_Used'])
# Out:
# <Axes: xlabel='Devices_Used', ylabel='Count'>

# %%
df[df['Average_Session_Length'] > 11.0]
# Out:
#      User_ID  Age Gender Location     Subscription_Start_Date  \
# 60        61   64  Other     West  2020-08-08 01:53:37.657676
# 980      981   43  Other  Central  2023-06-20 01:53:37.667714
#
#     Subscription_Type  Monthly_Payment Payment_Method  Monthly_Hours_Watched  \
# 60           Standard            14.99   Direct Debit              15.770722
# 980          Standard            14.99    Credit Card              21.455937
#
#     Favorite_Genre Devices_Used  Average_Session_Length  Content_ID  \
# 60           Drama       Tablet               11.417557        1018
# 980          Drama           TV               11.049324        1063
#
#      Rating_Given  Churned               Date_of_Churn Reason_for_Churn
# 60              3        1  2021-03-15 01:53:37.657676   Price increase
# 980             2        0                         NaN              NaN

# %%
# display the outliers for hours watched
df[df['Monthly_Hours_Watched'] > 130.00]
# Out:
#      User_ID  Age  Gender Location     Subscription_Start_Date  \
# 697      698   63  Female    South  2021-07-15 01:53:37.664613
#
#     Subscription_Type  Monthly_Payment Payment_Method  Monthly_Hours_Watched  \
# 697          Standard            14.99    Credit Card             139.170408
#
#     Favorite_Genre Devices_Used  Average_Session_Length  Content_ID  \
# 697         Sci-Fi       Mobile                1.332512        1064
#
#      Rating_Given  Churned Date_of_Churn Reason_for_Churn
# 697             2        0           NaN              NaN

# %%
# outliers appear to be accurate

# define terms for churn
Unsubscribed = df[df['Churned'] == 1]
Subscribed = df[df['Churned'] == 0]

# %%
# subscribers
print ("Subscribed: %i (%.1f%%)"%(len(Subscribed), float(len(Subscribed))/len(df)*100.0))
print ("Unsubscribed: %i (%.1f%%)"%(len(Unsubscribed), float(len(Unsubscribed))/len(df)*100.0))
print ("Total: %i"%len(df))

# relationship between age and churn
# Out:
# Subscribed: 754 (75.4%)
# Unsubscribed: 246 (24.6%)
# Total: 1000

# %%
df.Age.value_counts()
# Out:
# Age
# 45    27
# 52    27
# 50    27
# 43    26
# 66    26
# 49    25
# 18    24
# 70    23
# 22    23
# 56    23
# 41    22
# 54    22
# 40    21
# 65    21
# 25    21
# 33    21
# 69    21
# 42    21
# 29    21
# 68    21
# 62    20
# 53    20
# 19    20
# 64    20
# 20    20
# 34    20
# 46    19
# 61    19
# 36    18
# 39    18
# 47    18
# 38    18
# 26    17
# 67    16
# 30    16
# 51    16
# 58    16
# 28    16
# 59    16
# 44    16
# 31    15
# 57    15
# 23    15
# 32    15
# 21    15
# 37    14
# 35    14
# 27    14
# 24    13
# 48    13
# 55    13
# 63    12
# 60    10
# Name: count, dtype: int64

# %%
# to determine churn per age
df.groupby('Age')['Churned'].value_counts()
# Out:
# Age  Churned
# 18   0          17
#      1           7
# 19   0          14
#      1           6
# 20   0          16
#                 ..
# 68   1           8
# 69   0          15
#      1           6
# 70   0          20
#      1           3
# Name: count, Length: 105, dtype: int64

# %%
# to determine subscription across gender
df.Gender.value_counts()
# Out:
# Gender
# Other     336
# Male      334
# Female    330
# Name: count, dtype: int64

# %%
df.groupby('Gender')['Churned'].value_counts()
# Out:
# Gender  Churned
# Female  0          245
#         1           85
# Male    0          259
#         1           75
# Other   0          250
#         1           86
# Name: count, dtype: int64

# %%
# males churn less than other genders

df[['Gender', 'Churned']].groupby(['Gender'], as_index=False).mean()
# Out:
#    Gender   Churned
# 0  Female  0.257576
# 1    Male  0.224551
# 2   Other  0.255952

# %%
sns.barplot(x='Gender', y='Churned', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Churned'>

# %%
# listing of devices
df.Devices_Used.value_counts()
# Out:
# Devices_Used
# Mobile    408
# Tablet    217
# TV        201
# PC        174
# Name: count, dtype: int64

# %%
# a review of the devices used v. churn
df.groupby('Devices_Used')['Churned'].value_counts()
# Out:
# Devices_Used  Churned
# Mobile        0          277
#               1          131
# PC            0          147
#               1           27
# TV            0          157
#               1           44
# Tablet        0          173
#               1           44
# Name: count, dtype: int64

# %%
# churn rate per device used
df[['Devices_Used', 'Churned']].groupby(['Devices_Used'], as_index=False).mean()
# Out:
#   Devices_Used   Churned
# 0       Mobile  0.321078
# 1           PC  0.155172
# 2           TV  0.218905
# 3       Tablet  0.202765

# %%
# graph of same
sns.barplot(x='Devices_Used', y='Churned', data=df)
# Out:
# <Axes: xlabel='Devices_Used', ylabel='Churned'>

# %%
# comparisson of gender v. location
tab = pd.crosstab(df['Location'], df['Gender'])
print (tab)
# Out:
# Gender    Female  Male  Other
# Location
# Central       64    70     67
# East          73    64     63
# North         66    58     80
# South         57    64     58
# West          70    78     68

# %%
# stacked bar chart to show data above
tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.xlabel('Location')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
# comparrison bar  charts of churn rate across location and gender
sns.catplot(x='Gender', y='Churned', hue='Location', data=df, kind='bar', height=4, aspect=2)

# %%
# graph shows men in the south region have the least turnover, with a 80%+ retention rate.
# the graph shows the group with the highest churn rates @above 35% turnover is the other genderin the East region, folllowed by women, in the south region.

# Gender, Location, Rating vs. subscrition
sns.catplot(x='Gender', y='Churned', hue='Location', col='Rating_Given', data=df, kind='bar')

# %%
sns.catplot(x='Gender', y='Churned', hue='Location', col='Favorite_Genre', data=df, kind='bar')

# %%
sns.catplot(x='Gender', y='Churned', hue='Location', col='Devices_Used', data=df, kind='bar')

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

sns.violinplot(x="Rating_Given", y="Age", hue="Churned", data=df, split=True, ax=ax1)
sns.violinplot(x="Devices_Used", y="Age", hue="Churned", data=df, split=True, ax=ax2)
sns.violinplot(x="Gender", y="Age", hue="Churned", data=df, split=True, ax=ax3)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Drop 'User_ID' and 'Content_ID'
numeric_df = numeric_df.drop(['User_ID', 'Content_ID'],  axis=1)

plt.figure(figsize=(15, 6))
sns.heatmap(numeric_df.corr(), vmax=1.0, square=True, annot=True)
plt.show()

# %%
# Calculate average, standard deviation, and count of null values in 'Age' column
age_avg = df['Age'].mean()
age_std = df['Age'].std()
age_null_count = df['Age'].isnull().sum()

# Generate a list of random ages within one standard deviation of the mean
age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)

# Round the random ages to the nearest whole number (integer)
age_null_random_list = np.round(age_null_random_list, decimals=0)

# Replace NaN values in 'Age' column with rounded random ages and convert to integer
df.loc[df['Age'].isnull(), 'Age'] = age_null_random_list.astype(int)

# Create Age bands with integer cuts
df['AgeBand'] = pd.cut(df['Age'], 5, precision=0)

# Display Churn rate by Age bands
print(df[['AgeBand', 'Churned']].groupby(['AgeBand'], as_index=False).mean())
# Out:
#         AgeBand   Churned
# 0  (18.0, 28.0]  0.267677
# 1  (28.0, 39.0]  0.308140
# 2  (39.0, 49.0]  0.221239
# 3  (49.0, 60.0]  0.205128
# 4  (60.0, 70.0]  0.239234
# C:\Users\tauny\AppData\Local\Temp\ipykernel_59408\2684231413.py:19: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df[['AgeBand', 'Churned']].groupby(['AgeBand'], as_index=False).mean())

# %%
df.head()
# Out:
#    User_ID  Age  Gender Location     Subscription_Start_Date  \
# 0        1   56   Other  Central  2020-06-07 01:53:37.656934
# 1        2   69   Other     West  2024-02-21 01:53:37.656980
# 2        3   46  Female    North  2022-10-06 01:53:37.656995
# 3        4   32  Female     East  2022-01-04 01:53:37.657006
# 4        5   60  Female    North  2020-03-13 01:53:37.657017
#
#   Subscription_Type  Monthly_Payment Payment_Method  Monthly_Hours_Watched  \
# 0           Premium            19.99    Credit Card              31.513153
# 1          Standard            14.99    Credit Card               4.982277
# 2          Standard            14.99         PayPal               4.114953
# 3          Standard            14.99    Credit Card              60.244820
# 4          Standard            14.99    Credit Card               4.711855
#
#   Favorite_Genre Devices_Used  Average_Session_Length  Content_ID  \
# 0         Action           PC                1.195762        1023
# ...

# %%
# Map age according to AgeBand in the dataframe 'df'
df.loc[df['Age'] <= 17, 'Age'] = 0
df.loc[(df['Age'] > 28) & (df['Age'] <= 38), 'Age'] = 1
df.loc[(df['Age'] > 39) & (df['Age'] <= 49), 'Age'] = 2
df.loc[(df['Age'] > 49) & (df['Age'] <= 60), 'Age'] = 3
df.loc[df['Age'] > 30, 'Age'] = 4

# Display the updated Age mapping in the 'Age' column of DataFrame 'df'
print(df)
# Out:
#      User_ID  Age  Gender Location     Subscription_Start_Date  \
# 0          1    3   Other  Central  2020-06-07 01:53:37.656934
# 1          2    4   Other     West  2024-02-21 01:53:37.656980
# 2          3    2  Female    North  2022-10-06 01:53:37.656995
# 3          4    1  Female     East  2022-01-04 01:53:37.657006
# 4          5    3  Female    North  2020-03-13 01:53:37.657017
# ..       ...  ...     ...      ...                         ...
# 995      996   25   Other     East  2020-10-26 01:53:37.667884
# 996      997    4  Female     West  2020-05-06 01:53:37.667895
# 997      998    3   Other    South  2019-06-19 01:53:37.667906
# 998      999    4    Male     East  2020-11-13 01:53:37.667917
# 999     1000    1    Male    North  2022-07-10 01:53:37.667930
#
#     Subscription_Type  Monthly_Payment Payment_Method  Monthly_Hours_Watched  \
# 0             Premium            19.99    Credit Card              31.513153
# ...

# %%
df.head()
# Out:
#    User_ID  Age  Gender Location     Subscription_Start_Date  \
# 0        1    3   Other  Central  2020-06-07 01:53:37.656934
# 1        2    4   Other     West  2024-02-21 01:53:37.656980
# 2        3    2  Female    North  2022-10-06 01:53:37.656995
# 3        4    1  Female     East  2022-01-04 01:53:37.657006
# 4        5    3  Female    North  2020-03-13 01:53:37.657017
#
#   Subscription_Type  Monthly_Payment Payment_Method  Monthly_Hours_Watched  \
# 0           Premium            19.99    Credit Card              31.513153
# 1          Standard            14.99    Credit Card               4.982277
# 2          Standard            14.99         PayPal               4.114953
# 3          Standard            14.99    Credit Card              60.244820
# 4          Standard            14.99    Credit Card               4.711855
#
#   Favorite_Genre Devices_Used  Average_Session_Length  Content_ID  \
# 0         Action           PC                1.195762        1023
# ...

# %%
features_drop = {'User_ID', 'Subscription_Start_Date', 'Monthly_Hours_Watched', 'Average_Session_Length', 'Content_ID', 'Date_of_Churn', 'Reason_for_Churn', 'Subscription_Type', 'Monthly_Payment','Payment_Method','AgeBand'}
drop_columns = features_drop.intersection(df.columns)
df = df.drop(drop_columns, axis=1)

# Display the first few rows of the updated DataFrame
print(df.head())
# Out:
#    Age  Gender  Location  Favorite_Genre  Devices_Used  Rating_Given  Churned
# 0    3    <NA>      <NA>            <NA>          <NA>             5        0
# 1    4    <NA>      <NA>            <NA>          <NA>             1        0
# 2    2    <NA>      <NA>            <NA>          <NA>             2        0
# 3    1    <NA>      <NA>            <NA>          <NA>             1        0
# 4    3    <NA>      <NA>            <NA>          <NA>             4        0

# %%
# Define df set
X_df = df.drop('Churned', axis=1)
y_df = df['Churned']

# %%
X_df.shape, y_df.shape
# Out:
# ((1000, 6), (1000,))

# %%
# Importing Classifier Modules
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             1000 non-null   int64
#  1   Gender          0 non-null      Int64
#  2   Location        0 non-null      Int64
#  3   Favorite_Genre  0 non-null      Int64
#  4   Devices_Used    0 non-null      Int64
#  5   Rating_Given    1000 non-null   int64
#  6   Churned         1000 non-null   int64
# dtypes: Int64(4), int64(3)
# memory usage: 58.7 KB

# %%
# Replace missing values in 'Location' column with a placeholder value (e.g., -1)
df['Gender'] = df['Gender'].fillna(-1)

# Map 'Location' column to numerical values
location_mapping = {'Male': 0, 'Female': 1, 'Other': 2}
df['Gender'] = df['Gender'].map(location_mapping)

# Convert 'Location' column to a nullable integer type
df['Gender'] = df['Gender'].astype('Int64')

# %%
# Replace missing values in 'Location' column with a placeholder value (e.g., -1)
df['Location'] = df['Location'].fillna(-1)

# Map 'Location' column to numerical values
location_mapping = {'Central': 0, 'West': 1, 'North': 2, 'East': 3}
df['Location'] = df['Location'].map(location_mapping)

# Convert 'Location' column to a nullable integer type
df['Location'] = df['Location'].astype('Int64')

# %%
# Replace missing values in 'Location' column with a placeholder value (e.g., -1)
df['Favorite_Genre'] = df['Favorite_Genre'].fillna(-1)

# Map 'Location' column to numerical values
location_mapping = {'Action': 0, 'Drama': 1, 'Sci_Fy': 2, 'East': 3, 'Comedy':4, 'Documentary':5}
df['Favorite_Genre'] = df['Favorite_Genre'].map(location_mapping)

# Convert 'Location' column to a nullable integer type
df['Favorite_Genre'] = df['Favorite_Genre'].astype('Int64')

# %%
# Replace missing values in 'Location' column with a placeholder value (e.g., -1)
df['Devices_Used'] = df['Devices_Used'].fillna(-1)

# Map 'Location' column to numerical values
location_mapping = {'Tablet': 0, 'Modile': 1, 'TV': 2, 'PC': 3}
df['Devices_Used'] = df['Devices_Used'].map(location_mapping)

# Convert 'Location' column to a nullable integer type
df['Devices_Used'] = df['Devices_Used'].astype('Int64')

# %%
df.head()
# Out:
#    Age  Gender  Location  Favorite_Genre  Devices_Used  Rating_Given  Churned
# 0    3    <NA>      <NA>            <NA>          <NA>             5        0
# 1    4    <NA>      <NA>            <NA>          <NA>             1        0
# 2    2    <NA>      <NA>            <NA>          <NA>             2        0
# 3    1    <NA>      <NA>            <NA>          <NA>             1        0
# 4    3    <NA>      <NA>            <NA>          <NA>             4        0
